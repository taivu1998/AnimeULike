# %%
import urllib
import bs4

MAL_TOP_USER_LINK="https://myanimelist.net/reviews.php?st=mosthelpful"
CROLL_LINK="https://www.crunchyroll.com/videos/anime"

# %%
def link_to_soup(link,html=False):
    source = urllib.request.urlopen(link).read()
    soup=bs4.BeautifulSoup(source,'lxml' if html else 'html.parser')
    return soup
def numeric(s):
    #returns only digits
    lis=list(s)
    dig=lambda x:x>='0' and x<='9'
    return int(''.join(list(filter(lambda x:dig(x),lis))))

def child_find_all(x,tag="div"):
    return list(filter(lambda y:y.name==tag,x.contents))
def child_find(x,tag="div"):
    return child_find_all(x)[0]

# %%
def get_series(pg_start=0,pg_stop=0):
    links=[]
    for pg in range(pg_start,pg_stop+1):
        url="https://myanimelist.net/topanime.php?limit={}".format(50*pg)
        soup=link_to_soup(url)
        trs=soup.find_all("tr",class_="ranking-list")
        for tr in trs:
            td=tr.find_all('td')[1]
            links.append(td.a['href'])
    return links

# %%
def get_synopsis(soup):
    descr=soup.find('p',itemprop="description")
    return descr.text

def get_score(soup):
    rating=soup.find('span',itemprop="ratingValue")
    return float(rating.text)

def get_numerical_features(soup):
    # [#ranked, #popularity, #members, #favorites]
    extract=lambda x:''.join(list(filter(lambda y:y.isdigit(),list(x))))
    ranked_div=soup.find('div',attrs={"data-id":"info2"})
    ranked=ranked_div
    rank=extract(ranked.span.next_sibling)
    rank=int(rank)
    pop_div=ranked_div.parent
    divs=pop_div.find_all('div')
    fav=extract(divs[-2].span.next_sibling)
    members=extract(divs[-3].span.next_sibling)
    pop=extract(divs[-4].span.next_sibling)
    return [rank,pop,members,fav]

def get_reviews(soup):    
    #divs with e.g. id=score12912 identifies a user
    numeric_reviews=soup.find_all('div',attrs={"id":lambda x: x and "score" in x})
    #for each numeric review, 
    #every category is rating/10, [overall,story,animation,sound,character,enjoyment]
    numerics=[]
    for numeric_review in numeric_reviews:
        numeric=[]
        table=numeric_review.table
        for tr in table.find_all("tr"):
            numeric.append(int(tr.find_all('td')[-1].text))
        numerics.append(numeric)
        paragraphs=numeric_review.next_siblings
        review=""
        for p in paragraphs:
            if type(p)==bs4.element.Tag and p.name=="span": break
            elif type(p)==bs4.NavigableString: review+=p
        numerics.append(review)
    return numerics

    

def scrape_title(page):
    #feat_vec:[synopsis,score,numeric feats,
    #          reviewer's category ratings + reviewer's review for all reviewers]
    #e.g. "https://myanimelist.net/anime/5114/Fullmetal_Alchemist__Brotherhood"
    soup=link_to_soup(page)
    lis=[get_synopsis(soup),get_score(soup)]
    lis.extend(get_numerical_features(soup))
    i=1; a=-1; b=len(lis)
    while len(lis)>a:
        a=len(lis)
        lis.extend(get_reviews(link_to_soup(page+"/reviews?p={}".format(i))))
        i+=1
    return lis, len(lis)-b

# %%
def link_to_id(link):
    a=link.split('/')
    ind=a.index('anime')
    return int(a[ind+1])

def get_recs():
    dic=[]
    soup=link_to_soup(rec_url)
    trs=soup.find_all("tr")
    for i in range(len(trs)):
        tr=trs[i]
        tds=tr.find_all('td')
        td1,td2=tds[0],tds[1]
        get_name=lambda td:td.div.a['href']
        if not td1 or not td2: continue
        n1=get_name(td1)
        n2=get_name(td2)
        dic.append((link_to_id(n1),link_to_id(n2)))
    return dic

# %%
def get_pg_recs(page):
    #for robustness, only returns anime with at least two mentions
    soup=link_to_soup(page+"/userrecs")
    content=soup.find('div',attrs={'id':"content"})
    table=content.table
    td=list(filter(lambda x:x.name=="td",table.tr.contents))[1]
    class_match=lambda x:("borderClass" in x.attrs.get("class",dict()))
    rec_lambda=lambda x:x.name=="div" and class_match(x)
    divs=list(filter(rec_lambda,td.contents))
    all_recs=[]
    for div in divs:
        td=div.table.tr.find_all("td")[1]
        lis=(list(filter(lambda x:x.name=="div",td.contents)))
        name=lis[1].a["href"]
        rec=lis[2].div.text
        recs=[rec]
        try:
            no_recs=int(lis[3].a.strong.text)+1
        except IndexError:
            all_recs.append([name,1,recs])
            continue
        other_recs=lis[4].contents[1::2]
        for rec in other_recs:
            recs.append(rec.div.text)
        all_recs.append([name,no_recs,recs])
    return all_recs

# %%
get_pg_recs

# %%
def pg_reviews(link,ind):
    # returns [[id,#helpful,#rating]]
    ratings=[]
    soup=link_to_soup(link)
    reviews=[x.div for x in soup.find_all("div",class_="borderDark")]
    for review in reviews:
        rating=review.div.find_all("div")[-1].text
        rating=numeric(rating)
        all_divs=child_find_all(review,"div")
        entity=all_divs[1]
        entity=entity.find("a")["href"]
        anime_id=int(entity.split("/")[-2])
        helpful=all_divs[-1]
        helpful=int(helpful.table.tr.td.div.strong.span.text)
        ratings.append([ind,anime_id,helpful,rating])
    return ratings

def user_ratings(name,ind):
    pg_link=lambda i:"https://myanimelist.net/profile/{}/reviews?p={}".format(name,i)
    reviews=[]; l=0; i=0;
    while True:
        l=len(reviews)
        i+=1
        try:
            link=pg_link(i)
            reviews.extend(pg_reviews(link,ind))
            print("#reviews from {} is now {}".format(name,len(reviews)))
        except:
            break
    return reviews
        
def get_mal_top_users():
    soup=link_to_soup(MAL_TOP_USER_LINK)
    body=soup.body
    desc=body.find("div",attrs={"id":"content"})
    table=body.find("table")
    trs=table.find_all("tr")[1:]
    names=[]
    for tr in trs:
        td=tr.find_all("td")[1]
        ref=td.a["href"]
        name=ref.split('/')[-1]
        names.append(name)
    return names
    
def get_mal_user_ratings():
    IND=9
    users=get_mal_top_users()[IND:]
    ratings=[]
    for i in range(len(users)):
        ratings.extend(user_ratings(users[i],IND+i))
    return ratings

# %%
import numpy as np
np.savetxt('user_ratings_2.txt',get_mal_user_ratings(),'%d')
# Out:
# #reviews from literaturenerd is now 10
# #reviews from literaturenerd is now 20
# #reviews from literaturenerd is now 30
# #reviews from literaturenerd is now 40
# #reviews from literaturenerd is now 50
# #reviews from literaturenerd is now 60
# #reviews from literaturenerd is now 70
# #reviews from literaturenerd is now 80
# #reviews from literaturenerd is now 90
# #reviews from literaturenerd is now 100
# #reviews from literaturenerd is now 110
# #reviews from literaturenerd is now 120
# #reviews from literaturenerd is now 130
# #reviews from literaturenerd is now 140
# #reviews from literaturenerd is now 150
# #reviews from literaturenerd is now 160
# #reviews from literaturenerd is now 170
# #reviews from literaturenerd is now 180
# #reviews from literaturenerd is now 190
# #reviews from literaturenerd is now 200
# #reviews from literaturenerd is now 210
# #reviews from literaturenerd is now 220
# #reviews from literaturenerd is now 230
# #reviews from literaturenerd is now 240
# #reviews from literaturenerd is now 250
# #reviews from literaturenerd is now 260
# #reviews from literaturenerd is now 270
# #reviews from literaturenerd is now 280
# #reviews from literaturenerd is now 290
# #reviews from literaturenerd is now 300
# #reviews from literaturenerd is now 310
# #reviews from literaturenerd is now 320
# #reviews from literaturenerd is now 330
# #reviews from literaturenerd is now 340
# #reviews from literaturenerd is now 350
# #reviews from literaturenerd is now 360
# #reviews from literaturenerd is now 364
# #reviews from Master10K is now 10
# #reviews from Master10K is now 20
# #reviews from Master10K is now 30
# #reviews from Master10K is now 40
# #reviews from Master10K is now 50
# #reviews from Master10K is now 60
# #reviews from Master10K is now 70
# #reviews from Master10K is now 80
# #reviews from Master10K is now 90
# #reviews from Master10K is now 100
# #reviews from Master10K is now 110
# #reviews from Master10K is now 120
# #reviews from Master10K is now 130
# #reviews from Master10K is now 140
# #reviews from Master10K is now 150
# #reviews from Master10K is now 160
# #reviews from Master10K is now 170
# #reviews from Master10K is now 180
# #reviews from Master10K is now 190
# #reviews from Master10K is now 200
# #reviews from Ranivus is now 10
# #reviews from Ranivus is now 20
# #reviews from Ranivus is now 30
# #reviews from Ranivus is now 40
# #reviews from Ranivus is now 50
# #reviews from Ranivus is now 60
# #reviews from Ranivus is now 70
# #reviews from Ranivus is now 80
# #reviews from Ranivus is now 89
# #reviews from HellLyter is now 10
# #reviews from HellLyter is now 20
# #reviews from HellLyter is now 30
# #reviews from HellLyter is now 40
# #reviews from HellLyter is now 50
# #reviews from HellLyter is now 60
# #reviews from HellLyter is now 63
# #reviews from Beatnik is now 10
# #reviews from Beatnik is now 20
# #reviews from Beatnik is now 30
# #reviews from Beatnik is now 40
# #reviews from Beatnik is now 50
# #reviews from Beatnik is now 60
# #reviews from Beatnik is now 70
# #reviews from Beatnik is now 80
# #reviews from Beatnik is now 86
# #reviews from Detective is now 10
# #reviews from Detective is now 20
# #reviews from Detective is now 30
# #reviews from Detective is now 40
# #reviews from Detective is now 42
# #reviews from KaminaKai is now 10
# #reviews from KaminaKai is now 20
# #reviews from KaminaKai is now 30
# #reviews from KaminaKai is now 40
# #reviews from KaminaKai is now 50
# #reviews from KaminaKai is now 60
# #reviews from KaminaKai is now 62
# #reviews from Polyphemus is now 10
# #reviews from Polyphemus is now 20
# #reviews from Polyphemus is now 30
# #reviews from Polyphemus is now 32
# #reviews from ktulu007 is now 10
# #reviews from ktulu007 is now 20
# #reviews from ktulu007 is now 30
# #reviews from ktulu007 is now 40
# #reviews from ktulu007 is now 50
# #reviews from ktulu007 is now 60
# #reviews from ktulu007 is now 70
# #reviews from ktulu007 is now 80
# #reviews from ktulu007 is now 90
# #reviews from ktulu007 is now 100
# #reviews from ktulu007 is now 110
# #reviews from ktulu007 is now 120
# #reviews from ktulu007 is now 130
# #reviews from ktulu007 is now 140
# #reviews from ktulu007 is now 150
# #reviews from ktulu007 is now 160
# #reviews from ktulu007 is now 170
# #reviews from ktulu007 is now 180
# #reviews from ktulu007 is now 190
# #reviews from ktulu007 is now 200
# #reviews from ktulu007 is now 210
# #reviews from ktulu007 is now 220
# #reviews from ktulu007 is now 230
# #reviews from ktulu007 is now 240
# #reviews from ktulu007 is now 250
# #reviews from ktulu007 is now 260
# #reviews from ktulu007 is now 270
# #reviews from ktulu007 is now 280
# #reviews from ktulu007 is now 290
# #reviews from ktulu007 is now 300
# #reviews from ktulu007 is now 310
# #reviews from ktulu007 is now 320
# #reviews from ktulu007 is now 330
# #reviews from ktulu007 is now 340
# #reviews from ktulu007 is now 350
# #reviews from ktulu007 is now 360
# #reviews from ktulu007 is now 370
# #reviews from ktulu007 is now 380
# #reviews from ktulu007 is now 390
# #reviews from ktulu007 is now 400
# #reviews from ktulu007 is now 410
# #reviews from ktulu007 is now 420
# #reviews from ktulu007 is now 430
# #reviews from ktulu007 is now 440
# #reviews from ktulu007 is now 450
# #reviews from ktulu007 is now 460
# #reviews from ktulu007 is now 470
# #reviews from ktulu007 is now 480
# #reviews from ktulu007 is now 490
# #reviews from ktulu007 is now 500
# #reviews from ktulu007 is now 510
# #reviews from ktulu007 is now 520
# #reviews from ktulu007 is now 530
# #reviews from ktulu007 is now 540
# #reviews from ktulu007 is now 550
# #reviews from ktulu007 is now 560
# #reviews from ktulu007 is now 563
# #reviews from Krunchyman is now 10
# #reviews from Krunchyman is now 20
# #reviews from Krunchyman is now 30
# #reviews from Krunchyman is now 40
# #reviews from Krunchyman is now 50
# #reviews from Krunchyman is now 60
# #reviews from Krunchyman is now 70
# #reviews from Krunchyman is now 80
# #reviews from Krunchyman is now 90
# #reviews from Krunchyman is now 100
# #reviews from Krunchyman is now 109
# #reviews from 5camp is now 10
# #reviews from 5camp is now 20
# #reviews from 5camp is now 30
# #reviews from 5camp is now 40
# #reviews from 5camp is now 50
# #reviews from 5camp is now 60
# #reviews from 5camp is now 70
# #reviews from 5camp is now 80
# #reviews from 5camp is now 84
# #reviews from kiriska is now 10
# #reviews from kiriska is now 20
# #reviews from kiriska is now 30
# #reviews from kiriska is now 40
# #reviews from kiriska is now 50
# #reviews from kiriska is now 57
# #reviews from TheCriticsClub is now 10
# #reviews from TheCriticsClub is now 11
# #reviews from Link_of_Hyrule is now 10
# #reviews from Link_of_Hyrule is now 20
# #reviews from Link_of_Hyrule is now 30
# #reviews from Link_of_Hyrule is now 40
# #reviews from Link_of_Hyrule is now 50
# #reviews from Link_of_Hyrule is now 60
# #reviews from Link_of_Hyrule is now 65
# #reviews from KANLen09 is now 10
# #reviews from KANLen09 is now 20
# #reviews from KANLen09 is now 30
# #reviews from KANLen09 is now 40
# #reviews from KANLen09 is now 50
# #reviews from KANLen09 is now 60
# #reviews from KANLen09 is now 70
# #reviews from KANLen09 is now 80
# #reviews from KANLen09 is now 90
# #reviews from KANLen09 is now 100
# #reviews from KANLen09 is now 110
# #reviews from KANLen09 is now 120
# #reviews from KANLen09 is now 130
# #reviews from KANLen09 is now 140
# #reviews from KANLen09 is now 150
# #reviews from KANLen09 is now 160
# #reviews from KANLen09 is now 170
# #reviews from KANLen09 is now 180
# #reviews from KANLen09 is now 190
# #reviews from KANLen09 is now 200
# #reviews from KANLen09 is now 210
# #reviews from KANLen09 is now 220
# #reviews from KANLen09 is now 223
# #reviews from Inferno792 is now 10
# #reviews from Inferno792 is now 20
# #reviews from Inferno792 is now 28
# #reviews from Venneh is now 10
# #reviews from Venneh is now 20
# #reviews from Venneh is now 30
# #reviews from Venneh is now 40
# #reviews from Venneh is now 50
# #reviews from Venneh is now 60
# #reviews from Venneh is now 70
# #reviews from Venneh is now 78
# #reviews from 8thSin is now 10
# #reviews from 8thSin is now 20
# #reviews from 8thSin is now 30
# #reviews from 8thSin is now 40
# #reviews from 8thSin is now 47
# #reviews from Xyik is now 8
# #reviews from Pipe is now 10
# #reviews from Pipe is now 20
# #reviews from Pipe is now 30
# #reviews from Pipe is now 40
# #reviews from Pipe is now 50
# #reviews from Pipe is now 56
# #reviews from CodeBlazeFate is now 10
# #reviews from CodeBlazeFate is now 20
# #reviews from CodeBlazeFate is now 30
# #reviews from CodeBlazeFate is now 40
# #reviews from CodeBlazeFate is now 50
# #reviews from CodeBlazeFate is now 60
# #reviews from CodeBlazeFate is now 70
# #reviews from CodeBlazeFate is now 80
# #reviews from CodeBlazeFate is now 90
# #reviews from CodeBlazeFate is now 100
# #reviews from CodeBlazeFate is now 110
# #reviews from CodeBlazeFate is now 120
# #reviews from CodeBlazeFate is now 130
# #reviews from CodeBlazeFate is now 140
# #reviews from CodeBlazeFate is now 150
# #reviews from CodeBlazeFate is now 160
# #reviews from CodeBlazeFate is now 169
# #reviews from MozillaFennekin is now 10
# #reviews from MozillaFennekin is now 20
# #reviews from MozillaFennekin is now 30
# #reviews from MozillaFennekin is now 38
# #reviews from TakamakiJoker is now 10
# #reviews from TakamakiJoker is now 20
# #reviews from TakamakiJoker is now 30
# #reviews from TakamakiJoker is now 40
# #reviews from TakamakiJoker is now 50
# #reviews from TakamakiJoker is now 60
# #reviews from TakamakiJoker is now 70
# #reviews from TakamakiJoker is now 80
# #reviews from TakamakiJoker is now 90
# #reviews from TakamakiJoker is now 100
# #reviews from TakamakiJoker is now 110
# #reviews from TakamakiJoker is now 117
# #reviews from BanjoTheBear is now 10
# #reviews from BanjoTheBear is now 20
# #reviews from BanjoTheBear is now 30
# #reviews from BanjoTheBear is now 40
# #reviews from BanjoTheBear is now 50
# #reviews from BanjoTheBear is now 60
# #reviews from BanjoTheBear is now 70
# #reviews from BanjoTheBear is now 80
# #reviews from BanjoTheBear is now 90
# #reviews from BanjoTheBear is now 100
# #reviews from BanjoTheBear is now 110
# #reviews from BanjoTheBear is now 120
# #reviews from BanjoTheBear is now 130
# #reviews from BanjoTheBear is now 140
# #reviews from BanjoTheBear is now 150
# #reviews from BanjoTheBear is now 160
# #reviews from BanjoTheBear is now 170
# #reviews from BanjoTheBear is now 180
# #reviews from BanjoTheBear is now 190
# #reviews from BanjoTheBear is now 200
# #reviews from BanjoTheBear is now 210
# #reviews from BanjoTheBear is now 220
# #reviews from BanjoTheBear is now 230
# #reviews from BanjoTheBear is now 240
# #reviews from BanjoTheBear is now 250
# #reviews from BanjoTheBear is now 260
# #reviews from BanjoTheBear is now 270
# #reviews from BanjoTheBear is now 280
# #reviews from BanjoTheBear is now 290
# #reviews from BanjoTheBear is now 300
# #reviews from BanjoTheBear is now 302
# #reviews from DannyTheDonkey is now 10
# #reviews from DannyTheDonkey is now 19
# #reviews from kekekeKaj is now 10
# #reviews from kekekeKaj is now 20
# #reviews from kekekeKaj is now 30
# #reviews from kekekeKaj is now 40
# #reviews from kekekeKaj is now 50
# #reviews from kekekeKaj is now 60
# #reviews from kekekeKaj is now 70
# #reviews from kekekeKaj is now 80
# #reviews from kekekeKaj is now 90
# #reviews from kekekeKaj is now 100
# #reviews from kekekeKaj is now 110
# #reviews from kekekeKaj is now 120
# #reviews from kekekeKaj is now 130
# #reviews from kekekeKaj is now 140
# #reviews from kekekeKaj is now 150
# #reviews from kekekeKaj is now 160
# #reviews from kekekeKaj is now 170
# #reviews from kekekeKaj is now 173
# #reviews from Lindle is now 10
# #reviews from Lindle is now 20
# #reviews from Lindle is now 30
# #reviews from Lindle is now 40
# #reviews from Lindle is now 50
# #reviews from Lindle is now 58
# #reviews from Xinil is now 10
# #reviews from Xinil is now 17
# #reviews from Nyron is now 10
# #reviews from Nyron is now 20
# #reviews from Nyron is now 30
# #reviews from jet2r0cks is now 10
# #reviews from jet2r0cks is now 20
# #reviews from jet2r0cks is now 30
# #reviews from jet2r0cks is now 40
# #reviews from jet2r0cks is now 50
# #reviews from jet2r0cks is now 60
# #reviews from jet2r0cks is now 70
# #reviews from jet2r0cks is now 79
# #reviews from streetlights is now 3
# #reviews from DangoSage is now 10
# #reviews from DangoSage is now 20
# #reviews from DangoSage is now 30
# #reviews from PyraXadon is now 10
# #reviews from PyraXadon is now 20
# #reviews from PyraXadon is now 30
# #reviews from PyraXadon is now 40
# #reviews from PyraXadon is now 50
# #reviews from PyraXadon is now 60
# #reviews from PyraXadon is now 70
# #reviews from PyraXadon is now 80
# #reviews from PyraXadon is now 90
# #reviews from PyraXadon is now 100
# #reviews from PyraXadon is now 110
# #reviews from PyraXadon is now 120
# #reviews from PyraXadon is now 130
# #reviews from PyraXadon is now 140
# #reviews from PyraXadon is now 150
# #reviews from PyraXadon is now 160
# #reviews from PyraXadon is now 170
# #reviews from PyraXadon is now 180
# #reviews from PyraXadon is now 190
# #reviews from PyraXadon is now 200
# #reviews from PyraXadon is now 210
# #reviews from PyraXadon is now 220
# #reviews from PyraXadon is now 230
# #reviews from PyraXadon is now 240
# #reviews from PyraXadon is now 250
# #reviews from PyraXadon is now 260
# #reviews from PyraXadon is now 270
# #reviews from PyraXadon is now 280
# #reviews from PyraXadon is now 290
# #reviews from PyraXadon is now 300
# #reviews from PyraXadon is now 310
# #reviews from PyraXadon is now 320
# #reviews from PyraXadon is now 330
# #reviews from PyraXadon is now 340
# #reviews from PyraXadon is now 347
# #reviews from Satire is now 10
# #reviews from Satire is now 20
# #reviews from Satire is now 30
# #reviews from Satire is now 31
# #reviews from Marinate1016 is now 10
# #reviews from Marinate1016 is now 20
# #reviews from Marinate1016 is now 30
# #reviews from Marinate1016 is now 40
# #reviews from Marinate1016 is now 50
# #reviews from Marinate1016 is now 60
# #reviews from Marinate1016 is now 70
# #reviews from Marinate1016 is now 80
# #reviews from Marinate1016 is now 90
# #reviews from Marinate1016 is now 100
# #reviews from Marinate1016 is now 110
# #reviews from Marinate1016 is now 113
# #reviews from LeaderTGW is now 10
# #reviews from LeaderTGW is now 20
# #reviews from LeaderTGW is now 30
# #reviews from LeaderTGW is now 40
# #reviews from LeaderTGW is now 50
# #reviews from LeaderTGW is now 60
# #reviews from LeaderTGW is now 70
# #reviews from LeaderTGW is now 73
# #reviews from lawlmartz is now 10
# #reviews from lawlmartz is now 20
# #reviews from lawlmartz is now 30
# #reviews from lawlmartz is now 40
# #reviews from lawlmartz is now 50
# #reviews from lawlmartz is now 60
# #reviews from lawlmartz is now 70
# #reviews from lawlmartz is now 80
# #reviews from lawlmartz is now 90
# #reviews from lawlmartz is now 100
# #reviews from lawlmartz is now 110
# #reviews from lawlmartz is now 120
# #reviews from lawlmartz is now 123
# #reviews from LemonLyme is now 2
# #reviews from Foggle is now 3
# #reviews from LordAura is now 4
# #reviews from GonzoLewd is now 10
# #reviews from GonzoLewd is now 20
# #reviews from GonzoLewd is now 30
# #reviews from GonzoLewd is now 40
# #reviews from GonzoLewd is now 50
# #reviews from GonzoLewd is now 60
# #reviews from GonzoLewd is now 70
# #reviews from GonzoLewd is now 80
# #reviews from GonzoLewd is now 90
# #reviews from GonzoLewd is now 92

# %%
users=get_mal_top_users()

# %%
with open('id_to_username.txt','w+') as f:
    for i,username in enumerate(users):
        f.write("{} {}\n".format(i,username))
